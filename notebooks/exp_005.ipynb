# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Experimental 005

# %% [markdown]
# ## Setup

# %%
import ctypes
import os
import site
# nvidia pip packages内のlibcusparseLtをプリロード（PyTorch GPU版用）
_site_packages = site.getsitepackages()[0]
_cusparselt_so = os.path.join(_site_packages, "nvidia", "cusparselt", "lib", "libcusparseLt.so.0")
if os.path.isfile(_cusparselt_so):
    ctypes.cdll.LoadLibrary(_cusparselt_so)

from multiprocessing import process
from athena_analyze.data.processor import DataProcessor
from utils.logging import setup_logging
from utils.plotter import Plotter
from utils.config import load_config_section, load_config

_log = setup_logging()
data_cfg = load_config_section("../config/config.yml", "data")
processor = DataProcessor(data_folder=data_cfg["raw"])
dfs = []
dfs.append(processor.load_data("ETTh1.csv"))
dfs.append(processor.load_data("ETTh2.csv"))
exp_name = "exp_005"
plotter = Plotter(f"../reports/figures/{exp_name}")

general_cfg_path = "../config/config.yml"
exp_cfg_path = f"../config/{exp_name}.yml"
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/local/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/usr/local/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/usr/local/Cellar/python@3.12/3.12.9/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3123, in run_cell
#     result = self._run_cell(
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/mr/9ycqbh915_5f4hxrq1w5yh6m0000gq/T/ipykernel_14428/2062569217.py", line 11, in <module>
#     from athena_analyze.data.processor import DataProcessor
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py", line 6, in <module>
#     from torch.utils.data import Dataset
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# 2026-02-09 10:10:15,046 - athena-assignment - DEBUG - DataProcessor initialized with data folder: ../data/raw
# 2026-02-09 10:10:15,123 - athena-assignment - DEBUG - Plotter initialized with output folder: ../reports/figures/exp_005

# %% [markdown]
# # Preprocess
#
# MSTLを用いて周期性の分解を行う。

# %% [markdown]
# ## EDA
#
# exp_001のデータがどのような周期性を持っているかを確認する。

# %%
from anyio import Path
import pandas as pd
from athena_analyze.eda.analyzer import analyze_periodicity, compute_acf, compute_pacf
from athena_analyze.eda.visualize import plot_acf, plot_pacf, plot_power_spectrum

for h in ["h1"]:
    train_df = processor.load_data(f"exp_005/train_{h}.parquet", data_folder=Path("../data/experiment/"))
    test_df = processor.load_data(f"exp_005/test_{h}.parquet", data_folder=Path("../data/experiment/"))
    predict_df = processor.load_data(f"exp_005/predictions_tft_{h}.parquet", data_folder=Path("../data/experiment/"))
    # plot_df = pd.concat([train_df, test_df])
    plot_df = train_df.copy()

    cols = ["OT", "HUFL", "HULL", "MUFL", "MULL", "LUFL", "LULL"]
    results = {}

    for c in cols:
        _log.info(f"Analyzing column: {c}")
        _c = f"stl_{c}_resid"
        periods_df, power_df = analyze_periodicity(plot_df, max_period=2500, fs=1, target_col=_c)
        results[c] = {"periods" : periods_df, "power": power_df}
        acf_df = compute_acf(plot_df, target_col=_c)
        pacf_df = compute_pacf(plot_df, target_col=_c)
        results[c]["acf"] = acf_df
        results[c]["pacf"] = pacf_df
    for c in cols:
        _log.info(f"Top periods for column: {c}")
        acf_fig, _ = plot_acf(results[c]["acf"])
        pacf_fig, _ = plot_pacf(results[c]["pacf"])
        power_fig, _ = plot_power_spectrum(results[c]["power"])
        plotter.save_plot(acf_fig, f"{h}_{c.lower()}_acf.png")
        plotter.save_plot(pacf_fig, f"{h}_{c.lower()}_pacf.png")
        plotter.save_plot(power_fig, f"{h}_{c.lower()}_power_spectrum.png")
        del acf_fig, pacf_fig, power_fig
# Out:
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py:41: RuntimeWarning: coroutine 'Path.exists' was never awaited
#   if not file_path.exists():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py:41: RuntimeWarning: coroutine 'Path.exists' was never awaited
#   if not file_path.exists():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py:41: RuntimeWarning: coroutine 'Path.exists' was never awaited
#   if not file_path.exists():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2026-02-09 10:10:18,466 - athena-assignment - INFO - Analyzing column: OT
# 2026-02-09 10:10:18,471 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_OT_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:10:18,486 - athena-assignment - INFO - Detected 5 significant periods for stl_OT_resid
# 2026-02-09 10:10:18,486 - athena-assignment - DEBUG - Top period: 1175.8 (relative power: 1.000)
# 2026-02-09 10:10:18,487 - athena-assignment - DEBUG - Computing ACF for column: stl_OT_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:10:18,491 - athena-assignment - DEBUG - Computing PACF for column: stl_OT_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:10:28,695 - athena-assignment - INFO - Analyzing column: HUFL
# 2026-02-09 10:10:28,698 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_HUFL_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:10:28,705 - athena-assignment - INFO - Detected 5 significant periods for stl_HUFL_resid
# 2026-02-09 10:10:28,706 - athena-assignment - DEBUG - Top period: 63.4 (relative power: 1.000)
# 2026-02-09 10:10:28,706 - athena-assignment - DEBUG - Computing ACF for column: stl_HUFL_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:10:28,707 - athena-assignment - DEBUG - Computing PACF for column: stl_HUFL_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:10:38,673 - athena-assignment - INFO - Analyzing column: HULL
# 2026-02-09 10:10:38,674 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_HULL_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:10:38,681 - athena-assignment - INFO - Detected 5 significant periods for stl_HULL_resid
# 2026-02-09 10:10:38,681 - athena-assignment - DEBUG - Top period: 646.7 (relative power: 1.000)
# 2026-02-09 10:10:38,682 - athena-assignment - DEBUG - Computing ACF for column: stl_HULL_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:10:38,683 - athena-assignment - DEBUG - Computing PACF for column: stl_HULL_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:10:48,935 - athena-assignment - INFO - Analyzing column: MUFL
# 2026-02-09 10:10:48,936 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_MUFL_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:10:48,943 - athena-assignment - INFO - Detected 5 significant periods for stl_MUFL_resid
# 2026-02-09 10:10:48,944 - athena-assignment - DEBUG - Top period: 380.4 (relative power: 1.000)
# 2026-02-09 10:10:48,944 - athena-assignment - DEBUG - Computing ACF for column: stl_MUFL_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:10:48,946 - athena-assignment - DEBUG - Computing PACF for column: stl_MUFL_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:10:59,051 - athena-assignment - INFO - Analyzing column: MULL
# 2026-02-09 10:10:59,051 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_MULL_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:10:59,058 - athena-assignment - INFO - Detected 5 significant periods for stl_MULL_resid
# 2026-02-09 10:10:59,058 - athena-assignment - DEBUG - Top period: 22.6 (relative power: 1.000)
# 2026-02-09 10:10:59,059 - athena-assignment - DEBUG - Computing ACF for column: stl_MULL_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:10:59,060 - athena-assignment - DEBUG - Computing PACF for column: stl_MULL_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:11:08,969 - athena-assignment - INFO - Analyzing column: LUFL
# 2026-02-09 10:11:08,969 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_LUFL_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:11:08,977 - athena-assignment - INFO - Detected 5 significant periods for stl_LUFL_resid
# 2026-02-09 10:11:08,978 - athena-assignment - DEBUG - Top period: 1175.8 (relative power: 1.000)
# 2026-02-09 10:11:08,978 - athena-assignment - DEBUG - Computing ACF for column: stl_LUFL_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:11:08,980 - athena-assignment - DEBUG - Computing PACF for column: stl_LUFL_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:11:18,643 - athena-assignment - INFO - Analyzing column: LULL
# 2026-02-09 10:11:18,645 - athena-assignment - DEBUG - Analyzing periodicity for column: stl_LULL_resid with fs=1 and max_period=2500 (data length: 12934)
# 2026-02-09 10:11:18,659 - athena-assignment - INFO - Detected 5 significant periods for stl_LULL_resid
# 2026-02-09 10:11:18,659 - athena-assignment - DEBUG - Top period: 24.0 (relative power: 1.000)
# 2026-02-09 10:11:18,659 - athena-assignment - DEBUG - Computing ACF for column: stl_LULL_resid with max_lag=6467 (data length: 12934)
# 2026-02-09 10:11:18,662 - athena-assignment - DEBUG - Computing PACF for column: stl_LULL_resid with max_lag=1000 (data length: 12934)
# 2026-02-09 10:11:29,192 - athena-assignment - INFO - Top periods for column: OT
# 2026-02-09 10:11:29,783 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_ot_acf.png
# 2026-02-09 10:11:29,837 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_ot_pacf.png
# 2026-02-09 10:11:30,053 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_ot_power_spectrum.png
# 2026-02-09 10:11:30,053 - athena-assignment - INFO - Top periods for column: HUFL
# 2026-02-09 10:11:30,544 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_hufl_acf.png
# 2026-02-09 10:11:30,604 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_hufl_pacf.png
# 2026-02-09 10:11:30,824 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_hufl_power_spectrum.png
# 2026-02-09 10:11:30,824 - athena-assignment - INFO - Top periods for column: HULL
# 2026-02-09 10:11:31,108 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_hull_acf.png
# 2026-02-09 10:11:31,170 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_hull_pacf.png
# 2026-02-09 10:11:31,342 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_hull_power_spectrum.png
# 2026-02-09 10:11:31,342 - athena-assignment - INFO - Top periods for column: MUFL
# 2026-02-09 10:11:31,754 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_mufl_acf.png
# 2026-02-09 10:11:31,829 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_mufl_pacf.png
# 2026-02-09 10:11:32,134 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_mufl_power_spectrum.png
# 2026-02-09 10:11:32,134 - athena-assignment - INFO - Top periods for column: MULL
# 2026-02-09 10:11:32,501 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_mull_acf.png
# 2026-02-09 10:11:32,568 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_mull_pacf.png
# 2026-02-09 10:11:32,800 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_mull_power_spectrum.png
# 2026-02-09 10:11:32,801 - athena-assignment - INFO - Top periods for column: LUFL
# 2026-02-09 10:11:33,279 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_lufl_acf.png
# 2026-02-09 10:11:33,337 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_lufl_pacf.png
# 2026-02-09 10:11:33,554 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_lufl_power_spectrum.png
# 2026-02-09 10:11:33,554 - athena-assignment - INFO - Top periods for column: LULL
# 2026-02-09 10:11:33,901 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_lull_acf.png
# 2026-02-09 10:11:33,953 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_lull_pacf.png
# 2026-02-09 10:11:34,328 - athena-assignment - DEBUG - Plot saved to ../reports/figures/exp_005/h1_lull_power_spectrum.png

# %%
test_df.head()
# Out:
#                  date      HUFL      HULL      MUFL      MULL      LUFL  \
# 0 2018-02-01 14:00:00 -2.344374  0.473496 -2.560091  0.312154  0.520850
# 1 2018-02-01 15:00:00 -0.261580  0.408365 -0.514791  0.369170  0.833308
# 2 2018-02-01 16:00:00 -0.613844  0.050140 -0.861403  0.292790  0.963072
# 3 2018-02-01 17:00:00  0.878287  0.310667  0.610099  0.330980  1.482983
# 4 2018-02-01 18:00:00  1.230550  0.408365  0.894200  0.140030  1.925206
#
#        LULL        OT      year     month  ...  MULL_ma_72  MULL_ma_168  \
# 0  0.602501 -0.952773  2.295863 -1.465244  ...    0.606818     0.370759
# 1  0.458515 -1.214097  2.295863 -1.465244  ...    0.610948     0.369199
# 2  0.216430 -1.229853  2.295863 -1.465244  ...    0.614765     0.367072
# 3  0.023395 -1.253599  2.295863 -1.465244  ...    0.620812     0.366929
# 4  0.168962 -1.229853  2.295863 -1.465244  ...    0.625587     0.366646
#
#      sin_24    cos_24   sin_168   cos_168  sin_2160  cos_2160  sin_8760  \
# 0 -2.280865 -1.130131 -1.755178 -0.946015  1.701318 -1.736581  1.731274
# 1 -2.281533 -1.129980 -1.755461 -0.945940  1.701580 -1.736859  1.731550
# 2 -2.282035 -1.129866 -1.755674 -0.945884  1.701776 -1.737068  1.731757
# 3 -2.282703 -1.129714 -1.755957 -0.945809  1.702038 -1.737346  1.732032
# 4 -2.283372 -1.129562 -1.756241 -0.945735  1.702299 -1.737625  1.732308
#
#    cos_8760
# 0 -1.741560
# 1 -1.741841
# 2 -1.742051
# 3 -1.742332
# 4 -1.742613
#
# [5 rows x 102 columns]

# %%
from athena_analyze.eda.visualize import plot_time_series, plot_pairplot

for h in ["h1"]:
    train_df = processor.load_data(f"exp_005/train_{h}.parquet", data_folder=Path("../data/experiment/"))
    test_df = processor.load_data(f"exp_005/test_{h}.parquet", data_folder=Path("../data/experiment/"))
    predict_df = processor.load_data(f"exp_005/predictions_tft_{h}.parquet", data_folder=Path("../data/experiment/"))
    test_df["stl_OT_pred"] = predict_df["predicted"]
    
    train_end_date = train_df["date"].max()

    cols = ["OT", "HUFL", "HULL", "MUFL", "MULL", "LUFL", "LULL"]
    for c in cols:
        pair_cols = [col for col in train_df.columns if col.startswith(f"stl_{c}")]
        pair_cols = pair_cols + ["stl_OT_resid", "stl_OT_trend"]
        pair_cols = list(set(pair_cols))
        display(train_df[pair_cols].dtypes)
        display(train_df[pair_cols].shape)
        pair_fig = plot_pairplot(train_df[pair_cols], figsize=(8,8))
        plotter.save_plot(pair_fig, f"{h}_{c.lower()}_pairplot.png")
    
    plot_df = pd.concat([train_df, test_df])

    for c in cols:
        _cols = [_col for _col in plot_df.columns if "stl" in _col and (c in _col)]
        plot_cols = [_col for _col in _cols if "trend" in _col or "resid" in _col or _col == c]
        plot_cols = plot_cols + [c]
        fig = plot_time_series(df=plot_df, date_col="date", value_cols=plot_cols, v_lines=[train_end_date])
        plotter.save_plot(fig, f"{h}_{c.lower()}_time.png")
        plot_cols = [_col for _col in _cols if "seasonal" in _col]
        fig = plot_time_series(df=plot_df, date_col="date", value_cols=plot_cols, v_lines=[train_end_date])
        plotter.save_plot(fig, f"{h}_{c.lower()}_seasonal_time.png")
# Out:
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py:41: RuntimeWarning: coroutine 'Path.exists' was never awaited
#   if not file_path.exists():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py:41: RuntimeWarning: coroutine 'Path.exists' was never awaited
#   if not file_path.exists():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/teramoto/dev/github/YHTR0257/athena-assignment/src/athena_analyze/data/processor.py:41: RuntimeWarning: coroutine 'Path.exists' was never awaited
#   if not file_path.exists():
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# stl_OT_trend            float64
# stl_OT_seasonal_24      float64
# stl_OT_seasonal_504     float64
# stl_OT_seasonal_720     float64
# stl_OT_seasonal_2160    float64
# stl_OT_resid            float64
# stl_OT_resid            float64
# stl_OT_trend            float64
# dtype: object
# (12934, 8)
# 2026-02-09 12:21:51,594 - athena-assignment - DEBUG - Creating pairplot for variables: all numeric columns
# 2026-02-09 12:21:51,595 - athena-assignment - DEBUG - Auto-selected numeric columns: ['stl_OT_trend', 'stl_OT_seasonal_24', 'stl_OT_seasonal_504', 'stl_OT_seasonal_720', 'stl_OT_seasonal_2160', 'stl_OT_resid', 'stl_OT_resid', 'stl_OT_trend']
# 2026-02-09 12:21:51,598 - athena-assignment - DEBUG - Plotting 12934 rows with 12 columns
# 2026-02-09 12:21:51,600 - athena-assignment - ERROR - Error creating pairplot: Data must be 1-dimensional, got ndarray of shape (12934, 4) instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 17
#      15     display(train_df[pair_cols].dtypes)
#      16     display(train_df[pair_cols].shape)
# ---> 17     pair_fig = plot_pairplot(train_df[pair_cols], figsize=(8,8))
#      18     plotter.save_plot(pair_fig, f"{h}_{c.lower()}_pairplot.png")
#      20 plot_df = pd.concat([train_df, test_df])
#
# File <string>:50, in plot_pairplot(df, **kwargs)
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:1251, in PairGrid.__init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1248 data = handle_data_source(data)
#    1250 # Sort out the variables that define the grid
# -> 1251 numeric_cols = self._find_numeric_cols(data)
#    1252 if hue in numeric_cols:
#    1253     numeric_cols.remove(hue)
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/seaborn/axisgrid.py:1674, in PairGrid._find_numeric_cols(self, data)
#    1672 numeric_cols = []
#    1673 for col in data:
# -> 1674     if variable_type(data[col]) == "numeric":
#    1675         numeric_cols.append(col)
#    1676 return numeric_cols
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/seaborn/_base.py:1495, in variable_type(vector, boolean_type)
#    1472 def variable_type(vector, boolean_type="numeric"):
#    1473     """
#    1474     Determine whether a vector contains numeric, categorical, or datetime data.
#    1475
#    (...)   1493         Name identifying the type of data in the vector.
#    1494     """
# -> 1495     vector = pd.Series(vector)
#    1497     # If a categorical dtype is set, infer categorical
#    1498     if isinstance(vector.dtype, pd.CategoricalDtype):
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/pandas/core/series.py:514, in Series.__init__(self, data, index, dtype, name, copy)
#     512         data = data.copy(deep=True)
#     513 else:
# --> 514     data = sanitize_array(data, index, dtype, copy)
#     515     data = SingleBlockManager.from_array(data, index, refs=refs)
#     517 NDFrame.__init__(self, data)
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/pandas/core/construction.py:647, in sanitize_array(data, index, dtype, copy, allow_2d)
#     645     else:
#     646         data = np.array(data, copy=copy)
# --> 647     return sanitize_array(
#     648         data,
#     649         index=index,
#     650         dtype=dtype,
#     651         copy=False,
#     652         allow_2d=allow_2d,
#     653     )
#     655 else:
#     656     _sanitize_non_ordered(data)
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/pandas/core/construction.py:681, in sanitize_array(data, index, dtype, copy, allow_2d)
#     670             subarr = cast(np.ndarray, subarr)
#     671             subarr = lib.maybe_convert_objects(
#     672                 subarr,
#     673                 # Here we do not convert numeric dtypes, as if we wanted that,
#    (...)    678                 dtype_if_all_nat=np.dtype("M8[s]"),
#     679             )
# --> 681 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     683 if isinstance(subarr, np.ndarray):
#     684     # at this point we should have dtype be None or subarr.dtype == dtype
#     685     dtype = cast(np.dtype, dtype)
#
# File ~/dev/github/YHTR0257/athena-assignment/.venv/lib/python3.12/site-packages/pandas/core/construction.py:740, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     738     if allow_2d:
#     739         return result
# --> 740     raise ValueError(
#     741         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     742     )
#     743 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     744     # i.e. NumpyEADtype("O")
#     746     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (12934, 4) instead
